# %% [markdown]
# # ASP工具箱教程1：从文件导入XS脚本到场景
# ### 攥写：<font color="grey">[babycat](https://github.com/babycat262)</font>        技术支持：<font color="grey">[Alian713](https://github.com/Divy1211)</font>

# %% [markdown]
#     在对帝国2战役进行设计时，有时需要将一些XS函数定义在场景内部以供后续调用，可以借助Python的 AoE2ScenarioParser工具包（以下称ASP），从外部文件导入XS脚本（并非从“地图”选项卡引用外部XS文件）。
#
# 场景加载XS脚本的方式有3种：
#  - 1.在“地图”选项卡中脚本文件文本框，填写外部XS文件的名称（不含扩展名），引用脚本。
#  - 2.手动将XS函数定义到场景内。(条件：脚本调用 / 效果：脚本调用)
#  - <font color="green">3.借助ASP，从 .xs文件导入XS脚本到场景中。</font>
#  - <font color="red">【注意】XS函数的定义（导入）触发器位置，应该在所有调用它的触发器之前。遵循先定义后调用的原则。</font>
#
# 前2种方式在文档《关于地编触发“脚本调用”的使用说明》.pdf 中已经做了介绍，此处将重点讲解第3种方式，利用ASP导入脚本到场景中。

# %% [markdown]
# ## 第一部分：从文件中导入XS基本功能 和自定义XS功能
#
# #### 步骤如下：
#  - 1.在地图编辑器中创建一个场景（此处有一个名为 **Sanatorium.aoe2scenario**的场景，已经画好地形图）
# <img src="./images/doc-101.png" width=800 height=300 align="center">
#
#  - 2.用ASP读取场景，导入外部XS文件中的函数（存放于xs目录下的**xs_func_mini.xs**，）该脚本中包含了[UGC网站中的XS基本函数](https://ugc.aoe2.rocks/general/xs/functions/)，以及一些常用自定义函数：
# <img src="./images/doc-102.png" align="center">

# %% [markdown]
# - 3. 安装AoE2ScenarioParser，并加载场景
# ```bash
# # 在终端执行以下命令安装 AoE2ScenarioParser
# $ pip install AoE2ScenarioParser
# ```

# %%
# 导入ASP库
from AoE2ScenarioParser.scenarios.aoe2_de_scenario import AoE2DEScenario
# 从utils中导入工具函数，实现对文件脚本的读取
from utils import load_const, load_function

# %%
# 设置玩家基本信息
infos = {
    "user": "babycat",
    "game_id": 76561198386517457,
}

# 输入/输出 场景名称
input_scx = "Sanatorium"
output_scx= "Sanatorium [XS]"
# 输入，输出路径
src_path = f"C:/Users/{infos['user']}/Games/Age of Empires 2 DE/{infos['game_id']}/resources/_common/scenario/{input_scx}.aoe2scenario"
des_path = f"C:/Users/{infos['user']}/Games/Age of Empires 2 DE/{infos['game_id']}/resources/_common/scenario/{output_scx}.aoe2scenario"
# des_path = f"./outputs/{output_scx}.aoe2scenario"

# %%
print(src_path)
print(des_path)
# Out:
# C:/Users/babycat/Games/Age of Empires 2 DE/76561198386517457/resources/_common/scenario/Sanatorium.aoe2scenario
# C:/Users/babycat/Games/Age of Empires 2 DE/76561198386517457/resources/_common/scenario/Sanatorium [XS].aoe2scenario

# %%
# 读取场景
scenario = AoE2DEScenario.from_file(src_path)
# 使用触发管理器查看所有触发
trigger_mgr = scenario.trigger_manager
print("原场景触发器数量： ", len(trigger_mgr.triggers))
# Out:
# [11:25:28] Reading file: 'C:/Users/babycat/Games/Age of Empires 2 DE/76561198386517457/resources/_common/scenario/Sanatorium.aoe2scenario'
# [11:25:28] Reading scenario file finished successfully.
#
# ############### Attributes ###############
# >>> Game version: 'DE'
# >>> Scenario version: 1.53
# >>> Scenario variant: 'Age of Empires 2'
# ##########################################
#
# [11:25:28] Loading scenario structure finished successfully.
# [11:25:28] Parsing scenario file...
# 	✔ FileHeadereHeader data...
# 	✔ DataHeaderaHeader data...
# 	✔ Messagesessages data...
# 	✔ Cinematicsematics data...
# 	✔ BackgroundImagendImage data...
# 	✔ PlayerDataTwoDataTwo data...
# 	✔ GlobalVictoryVictory data...
# 	✔ Diplomacyplomacy data...
# 	✔ OptionsOptions data...
# 	✔ Maping Map data...
# 	✔ Unitsg Units data...
# 	✔ Triggersriggers data...
# 	✔ Filesg Files data...
# [11:25:33] Parsing scenario file finished successfully.
#
# [11:25:33] Setting up managers ...
# 	✔ MessageManagereManager...
# 	✔ PlayerManagerrManager...
# 	✔ MapManagerpManager...
# 	✔ UnitManagertManager...
# 	✔ TriggerManagerrManager...
# 	✔ XsManagersManager...
# 	✔ OptionManagernManager...
# [11:25:35] Setting up managers finished successfully.
# 原场景触发器数量：  0

# %% [markdown]
# #### 从以上日志信息看到场景已经成功读取，且trigger_mgr中的触发数量是0（空列表）。接下来要给场景新建触发器，并从XS文件导入函数到场景中。

# %%
# （可选）创建标题触发，为你的场景/战役起个名字
title_trigger = trigger_mgr.add_trigger("*****《毛利人的村庄》*****", enabled=False)
# 查看触发名称
print(title_trigger.name)
# Out:
# *****《毛利人的村庄》*****

# %%
# 新建触发器，名称为XS_FUNC_TITLE所指定的名称，该触发器存放XS定义
# 【注意】将XS脚本作为条件定义导入场景中，该触发器状态必须要关闭，要设置 enabled=False
XS_FUNC_TITLE= r"XS函数定义"
fn_trigger = trigger_mgr.add_trigger(XS_FUNC_TITLE, enabled=False)
print(fn_trigger.name)
# Out:
# XS函数定义

# %%
# 用函数 load_function 读取 XS文件内容到列表中
_, fn_list = load_function("./xs/xs_func_mini.xs", sep='\n\n\n')
fn_list
# Out:
# ['const float EPS=0.000001;const float PI=3.1416;const float E_=2.7183;const int Inf=32768;',
#  'void _EA(int mode=-1,int id_=0,int attr=-1,float val_=0.0,int p=-1){if(mode>=0 && mode<=9){xsEffectAmount(mode,id_,attr,val_,p);}}',
#  'void _Chat(string msg="",string color="",float val_=-32768){if(val_!=-32768){msg=color+msg+": "+val_;} else{msg=color+msg;} xsChatData(msg);}',
#  'int _BoolArr(int arr_len=1,bool val_=false,string arr_name=""){return (xsArrayCreateBool(arr_len,val_,arr_name));}',
#  'int _IntArr(int arr_len=1,int val_=0,string arr_name=""){return (xsArrayCreateInt(arr_len,val_,arr_name));}',
#  'int _FloatArr(int arr_len=1,float val_=0.0,string arr_name=""){return (xsArrayCreateFloat(arr_len,val_,arr_name));}',
#  'int _StrArr(int arr_len=1,string val_="",string arr_name=""){return (xsArrayCreateString(arr_len,val_,arr_name));}',
#  'int _VecArr(int arr_len=1,vector val_=cOriginVector,string arr_name=""){return (xsArrayCreateVector(arr_len,val_,arr_name));}',
#  'bool _BArrG(int arr=-1,int index=0){return (xsArrayGetBool(arr,index));}',
#  'int _IArrG(int arr=-1,int index=0){return (xsArrayGetInt(arr,index));}',
#  'float _FArrG(int arr=-1,int index=0){return (xsArrayGetFloat(arr,index));}',
#  'string _SArrG(int arr=-1,int index=0){return (xsArrayGetString(arr,index));}',
#  'vector _VArrG(int arr=-1,int index=0){return (xsArrayGetVector(arr,index));}',
#  'int _BArrS(int arr=-1,int index=0,bool val_=false){return (xsArraySetBool(arr,index,val_));}',
#  'int _IArrS(int arr=-1,int index=0,int val_=0){return (xsArraySetInt(arr,index,val_));}',
#  'int _FArrS(int arr=-1,int index=0,float val_=0.0){return (xsArraySetFloat(arr,index,val_));}',
#  'int _SArrS(int arr=-1,int index=0,string val_=""){return (xsArraySetString(arr,index,val_));}',
#  'int _VArrS(int arr=-1,int index=0,vector val_=cOriginVector){return (xsArraySetVector(arr,index,val_));}',
#  'int _ArrSize(int arr=-1){return (xsArrayGetSize(arr));}',
#  'int _GameT(){ return (xsGetGameTime());}',
#  'int _OC(int p=0,int unit=-1){return (xsGetObjectCount(p,unit));}',
#  'int _OCT(int p=0,int unit=-1){return (xsGetObjectCountTotal(p,unit));}',
#  'int _Victory(){return (xsGetVictoryCondition());}',
#  'int _GPC(int p=0){return (xsGetPlayerCivilization(p));}',
#  'float _PA(int p=0,int src_id=-1){return (xsPlayerAttribute(p,src_id));}',
#  'void _SPA(int p=0,int src_id=-1,float amt_=0.0){xsSetPlayerAttribute(p,src_id,amt_);}',
#  'int _TV(int var_id=0){return (xsTriggerVariable(var_id));}',
#  'void _STV(int var_id=0,int val_=0){xsSetTriggerVariable(var_id,val_);}',
#  'bool _RT(int tech_id=-1,bool force=true,bool avilable=false,int p=-1){if(force && avilable) {return (false);}return (xsResearchTechnology(tech_id,force,avilable,p));}',
#  'bool _PInGame(int p=0){return (xsGetPlayerInGame(p));}',
#  'float round(float x_=0.0,int n=0){float num=0;int pn=pow(10,n);float pf=x_*pn;int ipf=1*pf; if(abs(pf-ipf)<0.5){num=1.0*ipf/pn;} else{num=1.0*(ipf+1)/pn;} return(num);}',
#  'int floor(float x_=0.0){return(0+x_);}',
#  'int ceil(float x_=0.0){int ix=x_; if(abs(x_-ix)>0){return(ix+1);} return(ix);}',
#  'float _Float(float x_=0.0){return (x_-(0+x_));}',
#  '',
#  'bool _NOT(bool flag=true){if(flag){return(false);} return(true);}',
#  'bool xsNum2Bool(float x_=0.0){if(x_>0.0){return (true);} return (false);}',
#  'int randLH(int low=0,int high=32768){return (xsGetRandomNumberLH(0,high-low)+low);}',
#  'int randLI(bool sign_=false){static int sign=1; if(sign_){sign=0-sign;} int ri=xsGetRandomNumber(); int I=randLH(0,30519); if(I>=30518){ri=randLH(0,16693);} int LI=sign*(32767*I+ri); return(LI);}',
#  'float random(bool sign_=false){static float sign=1.0;if(sign_){sign=0.0-sign;}float rn=xsGetRandomNumber();int I=xsGetRandomNumberLH(0,31);if(I>=30){rn=xsGetRandomNumberLH(0,16990);}rn=0.000001*sign*(rn+I*32767);static int fix=1; fix=0-fix;if((rn>0.83&&rn<0.88)&&(fix==1)){rn=rn-0.72;}return (rn);}',
#  'bool xsProbability(float prob=0.5){float rp=xsGetRandomNumber();int I=xsGetRandomNumberLH(0,31);if(I>=30){rp=xsGetRandomNumberLH(0,16990);} rp=0.000001*(rp+32767*I);static int fix=1; fix=0-fix;if((rp>=0.83 && rp<=0.88) && fix==1){rp=rp-0.72;}if(rp <= prob){return (true);}return (false);}',
#  'void xsExit(bool exit=true){if(exit){xsChatData("%NULL");}}']

# %% [markdown]
# #### 现在已经将XS文件中的内容读取到列表`fn_list`中。接着遍历该列表，把每个元素（XS功能）定义到场景中。

# %%
# 遍历 fn_list将其中每一项定义到场景
for fn in fn_list:
    fn_trigger.new_condition.script_call(fn)
print("XS函数基本导入成功！")
# Out:
# XS函数基本导入成功！

# %%
# 查看触发中的XS脚本导入情况
fn_trigger.conditions
# Out:
# [Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: const float EPS=0.000001;const float PI=3.1416;const float E_=2.7183;const int Inf=32768;
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _EA(int mode=-1,int id_=0,int attr=-1,float val_=0.0,int p=-1){if(mode>=0 && mode<=9){xsEffectAmount(mode,id_,attr,val_,p);}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _Chat(string msg="",string color="",float val_=-32768){if(val_!=-32768){msg=color+msg+": "+val_;} else{msg=color+msg;} xsChatData(msg);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _BoolArr(int arr_len=1,bool val_=false,string arr_name=""){return (xsArrayCreateBool(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _IntArr(int arr_len=1,int val_=0,string arr_name=""){return (xsArrayCreateInt(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _FloatArr(int arr_len=1,float val_=0.0,string arr_name=""){return (xsArrayCreateFloat(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _StrArr(int arr_len=1,string val_="",string arr_name=""){return (xsArrayCreateString(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _VecArr(int arr_len=1,vector val_=cOriginVector,string arr_name=""){return (xsArrayCreateVector(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _BArrG(int arr=-1,int index=0){return (xsArrayGetBool(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _IArrG(int arr=-1,int index=0){return (xsArrayGetInt(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float _FArrG(int arr=-1,int index=0){return (xsArrayGetFloat(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: string _SArrG(int arr=-1,int index=0){return (xsArrayGetString(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: vector _VArrG(int arr=-1,int index=0){return (xsArrayGetVector(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _BArrS(int arr=-1,int index=0,bool val_=false){return (xsArraySetBool(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _IArrS(int arr=-1,int index=0,int val_=0){return (xsArraySetInt(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _FArrS(int arr=-1,int index=0,float val_=0.0){return (xsArraySetFloat(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _SArrS(int arr=-1,int index=0,string val_=""){return (xsArraySetString(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _VArrS(int arr=-1,int index=0,vector val_=cOriginVector){return (xsArraySetVector(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _ArrSize(int arr=-1){return (xsArrayGetSize(arr));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _GameT(){ return (xsGetGameTime());}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _OC(int p=0,int unit=-1){return (xsGetObjectCount(p,unit));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _OCT(int p=0,int unit=-1){return (xsGetObjectCountTotal(p,unit));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _Victory(){return (xsGetVictoryCondition());}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _GPC(int p=0){return (xsGetPlayerCivilization(p));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float _PA(int p=0,int src_id=-1){return (xsPlayerAttribute(p,src_id));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _SPA(int p=0,int src_id=-1,float amt_=0.0){xsSetPlayerAttribute(p,src_id,amt_);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _TV(int var_id=0){return (xsTriggerVariable(var_id));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _STV(int var_id=0,int val_=0){xsSetTriggerVariable(var_id,val_);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _RT(int tech_id=-1,bool force=true,bool avilable=false,int p=-1){if(force && avilable) {return (false);}return (xsResearchTechnology(tech_id,force,avilable,p));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _PInGame(int p=0){return (xsGetPlayerInGame(p));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float round(float x_=0.0,int n=0){float num=0;int pn=pow(10,n);float pf=x_*pn;int ipf=1*pf; if(abs(pf-ipf)<0.5){num=1.0*ipf/pn;} else{num=1.0*(ipf+1)/pn;} return(num);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int floor(float x_=0.0){return(0+x_);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int ceil(float x_=0.0){int ix=x_; if(abs(x_-ix)>0){return(ix+1);} return(ix);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float _Float(float x_=0.0){return (x_-(0+x_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function:
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _NOT(bool flag=true){if(flag){return(false);} return(true);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool xsNum2Bool(float x_=0.0){if(x_>0.0){return (true);} return (false);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int randLH(int low=0,int high=32768){return (xsGetRandomNumberLH(0,high-low)+low);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int randLI(bool sign_=false){static int sign=1; if(sign_){sign=0-sign;} int ri=xsGetRandomNumber(); int I=randLH(0,30519); if(I>=30518){ri=randLH(0,16693);} int LI=sign*(32767*I+ri); return(LI);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float random(bool sign_=false){static float sign=1.0;if(sign_){sign=0.0-sign;}float rn=xsGetRandomNumber();int I=xsGetRandomNumberLH(0,31);if(I>=30){rn=xsGetRandomNumberLH(0,16990);}rn=0.000001*sign*(rn+I*32767);static int fix=1; fix=0-fix;if((rn>0.83&&rn<0.88)&&(fix==1)){rn=rn-0.72;}return (rn);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool xsProbability(float prob=0.5){float rp=xsGetRandomNumber();int I=xsGetRandomNumberLH(0,31);if(I>=30){rp=xsGetRandomNumberLH(0,16990);} rp=0.000001*(rp+32767*I);static int fix=1; fix=0-fix;if((rp>=0.83 && rp<=0.88) && fix==1){rp=rp-0.72;}if(rp <= prob){return (true);}return (false);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void xsExit(bool exit=true){if(exit){xsChatData("%NULL");}}
#  	}]

# %% [markdown]
# 从输出结果可以看出，basefn_trigger 的条件列表中，对应的 `xs_function`属性都正确赋以了一个XS函数脚本，如图所示：
# <img src="./images/doc-103.png" width=300 height=800>

# %%
# 将修改后的场景进行保存
scenario.write_to_file(des_path)
# Out:
# [11:27:31] Reconstructing sections and structs from managers...
# 	✔ MessageManagerssageManager...
# 	✔ PlayerManagerlayerManager...
# 	✔ MapManagerg MapManager...
# 	✔ UnitManager UnitManager...
# 	✔ TriggerManageriggerManager...
# 	✔ XsManagerng XsManager...
# 	✔ OptionManagerptionManager...
# [11:27:33] Reconstruction finished successfully.
#
# [11:27:33] File writing from structure started...
# 	✔ FileHeaderg FileHeader...
# 	✔ DataHeaderg DataHeader...
# 	✔ Messagesing Messages...
# 	✔ Cinematicsg Cinematics...
# 	✔ BackgroundImagekgroundImage...
# 	✔ PlayerDataTwolayerDataTwo...
# 	✔ GlobalVictorylobalVictory...
# 	✔ Diplomacyng Diplomacy...
# 	✔ Optionsting Options...
# 	✔ Maptructing Map...
# 	✔ Unitsucting Units...
# 	✔ Triggersing Triggers...
# 	✔ Filesucting Files...
# [11:27:34] File writing finished successfully.
# [11:27:34] File successfully written to: 'C:/Users/babycat/Games/Age of Empires 2 DE/76561198386517457/resources/_common/scenario/Sanatorium [XS].aoe2scenario'
# [11:27:34] Execution time from scenario read: 125.31s

# %% [markdown]
# ## 第二部分：从文件中导入用户定义(UDF)函数
#     用户自定义的UDF函数，可以实现除了基础函数外的特定功能。这些函数能够实现更灵活的功能定制。
# 假设现在有几个已实现的UDF函数：
#  - `enable_unit`: 启用指定单位与某个建筑中
#  - `unit_blast`：设置单位践踏
#  - `unit_charges`：设置单位蓄力
#  - `unit_combats`：设置单位作战能力
#  - `unit_projectiles`：设置单位抛掷物
#  - `proj_smart_mode`：设置抛掷物智能模式
#  - `units_transform`：单位形态转换（单位变身）

# %% [markdown]
# #### 下面是一个UDF函数的示例：
# ```c++
# /**
#  * @brief 设置单位蓄力
#  * @param unit: 单位ID
#  * @param charge_event: 蓄力事件。 {0:"无蓄力", 1:"有蓄力"}
#  * @param charge_type: 蓄力类型。 {0:"无蓄力攻击，不能闪避抛射物", 1:"蓄力攻击", 3:"蓄力范围攻击", 4:"闪避抛射物"}
#  * @param max_charge: 最大蓄力值，单位拥有的最大蓄力充能点数。 最大蓄力值 = 蓄力再生率*蓄力CD
#  * @param recharge_rate : 蓄力再生速率(点/秒)
#  * @param p: 玩家序号
#  * @param charge_cd: 蓄力充能周期（秒）。若该值设置成大于0的数值，则蓄力再生速率由以下公式确定：蓄力再生速率 = 最大蓄力值/蓄力CD
#  * @return <Bool> 若蓄力成功设置返回true，否则返回false
# **/
# bool unit_charges(int unit=0, int charge_event=0, int charge_type=0, float max_charge=0.0, float recharge_rate=0.0, int p=-1, float charge_cd=-1)
# {
#     if(charge_event==0 || (charge_type<0 || charge_type>4 || charge_type==2)) {return (false);}
#     if(charge_cd > 0) {recharge_rate = max_charge/charge_cd;}
#     xsEffectAmount(0, unit, 61, charge_event, p);
#     xsEffectAmount(0, unit, 62, charge_type, p);
#     xsEffectAmount(0, unit, 59, max_charge, p);
#     xsEffectAmount(0, unit, 60, recharge_rate, p);
#     return (true);
# }
# ```
#
# 这些函数已经在`UDF模块`中实现，在下面的单元格中将它导入：

# %%
#改变输出场景名称（可选）
des_path = des_path.replace('[XS]', '[XS_ALL]')
print(des_path)
# Out:
# C:/Users/babycat/Games/Age of Empires 2 DE/76561198386517457/resources/_common/scenario/Sanatorium [XS_ALL].aoe2scenario

# %%
# 从文件种加载UDF函数列表
udf_list = load_function("./xs/hero_skills.xs")[1]
udf_list
# Out:
# ['void unit_blast(int unit=-1,int blast_att=-1,int blast_def=-1,float blast_w=0.0,float blast_rate=0.0,int p=-1) {if(blast_att==0||blast_att==1||blast_att==2||blast_att==4||blast_att==64||blast_att==128) {xsEffectAmount(0,unit,44,blast_att,p);}if(blast_def==0||blast_def==1||blast_def==2||blast_def==4) {xsEffectAmount(0,unit,45,blast_def,p);}if(blast_w > 0.0) {xsEffectAmount(0,unit,22,blast_w,p);}if(blast_rate > 0.0 && blast_rate <= 1.0) {xsEffectAmount(0,unit,115,blast_rate,p);}else if(blast_rate < 0 && blast_rate > 0-255) {xsEffectAmount(0,unit,115,1*blast_rate,p);}}',
#  'bool unit_charges(int unit=-1,int charge_event=0,int charge_type=0,float max_charge=0.0,float recharge_rate=0.0,int p=-1,float charge_cd=-1) {if(charge_event==0||(charge_type<0||charge_type>4||charge_type==2)) {return (false);}if(charge_cd > 0) {recharge_rate=max_charge/charge_cd;}xsEffectAmount(0,unit,61,charge_event,p);xsEffectAmount(0,unit,62,charge_type,p);xsEffectAmount(0,unit,59,max_charge,p);xsEffectAmount(0,unit,60,recharge_rate,p);return (true);}',
#  'int unit_combats(int unit=-1,int ability=0,int p=-1) {if((unit>=0)&&(ability==0||ability==1||ability==2||ability==4 ||ability==8||ability==16||ability==32)){xsEffectAmount(0,unit,63,ability,p); return (ability);}return (-1);}',
#  'void unit_traits(int unit1=-1,int _trait=0,int unit2=0,int p=-1) { if(_trait==0||_trait==1||_trait==2||_trait==16) {xsEffectAmount(0,unit1,54,_trait,p);}else if(_trait==4) {xsEffectAmount(0,unit1,54,4,p);}  else if(_trait==8 && (unit2>=0 && unit2<1800)) {xsEffectAmount(0,unit1,54,8,p);xsEffectAmount(0,unit2,54,8,p);xsEffectAmount(0,unit1,56,unit2,p);xsEffectAmount(0,unit2,56,unit1,p);}else {}}',
#  'bool units_transform(int units_arr=-1,int p=-1) {int arr_size=xsArrayGetSize(units_arr);if(arr_size < 2) {return (false);}else {int unit1= -1;int unit2= -1;for(i=0; <arr_size) {unit1=xsArrayGetInt(units_arr,i);if(i==arr_size-1) {unit2=xsArrayGetInt(units_arr,0);}else {unit2=xsArrayGetInt(units_arr,i+1);}if(unit1<=0||unit2<=0){continue;}xsEffectAmount(0,unit1,54,8,p);xsEffectAmount(0,unit1,56,unit2,p);}return (true);}return (false);}',
#  'void unit_cloths(int unit=-1,int icon=0,vector attack_img=cInvalidVector,vector stand_img=cInvalidVector,vector death_img=cInvalidVector,vector  move_img=cInvalidVector,int death=-1,int p=-1){if(unit>0 && (p>=0 && p<=8)) {if(icon > 0) {xsEffectAmount(0,unit,25,icon,p);}if(attack_img != cInvalidVector) {xsEffectAmount(0,unit,70,xsVectorGetX(attack_img),p);}if(stand_img != cInvalidVector) {int simg1 = xsVectorGetX(stand_img);int simg2 = xsVectorGetY(stand_img);if(simg1>0) {xsEffectAmount(0,unit,71,simg1,p);}if(simg2>0) {xsEffectAmount(0,unit,72,simg2,p);}}if(death_img != cInvalidVector) {int dimg1 = xsVectorGetX(death_img);int dimg2 = xsVectorGetY(death_img);if(dimg1>0) {xsEffectAmount(0,unit,73,dimg1,p);}if(dimg2>0) {xsEffectAmount(0,unit,74,dimg2,p);}}if(move_img != cInvalidVector) {int mimg1 = xsVectorGetX(move_img);int mimg2 = xsVectorGetY(move_img);if(mimg1>0) {xsEffectAmount(0,unit,75,mimg1,p);}if(mimg2>0) {xsEffectAmount(0,unit,76,mimg2,p);}}if(death>-1 && death<2000) {xsEffectAmount(0,unit,57,death,p);}}}',
#  'void unit_projectiles(int unit=-1,int mproj=-1,int sproj=-1,int max_projs=1,int init_projs=1,int p=-1,float mpv=-1,float spv=-1,int mdu=-1,int sdu=-1,bool proj_sync=false) {if(mproj > 0) {xsEffectAmount(0,unit,16,mproj,p);}if(sproj > 0) {xsEffectAmount(0,unit,65,sproj,p);}if(max_projs>=init_projs && init_projs>=1) {xsEffectAmount(0,unit,107,max_projs,p);xsEffectAmount(0,unit,102,init_projs,p);}if(mpv > 0) {xsEffectAmount(0,mproj,5,mpv,p);}if(spv > 0) {xsEffectAmount(0,sproj,5,spv,p);}if(mdu > 0) {xsEffectAmount(0,mproj,57,mdu,p);}if(sdu > 0) {xsEffectAmount(0,sproj,57,sdu,p);}if(proj_sync) {xsEffectAmount(0,unit,63,16,p);}}',
#  'void proj_smart_mode(int proj=-1,int smart_mode=-1,int hit_mode=-1,int pass_mode=-1,float proj_arc=-1,int p=-1) {if(smart_mode>=0 && smart_mode<=3){xsEffectAmount(0,proj,19,smart_mode,p);}if((hit_mode>=0 && hit_mode<=3)&&(pass_mode>=0 && pass_mode<=1)){xsEffectAmount(0,proj,67,hit_mode,p);xsEffectAmount(0,proj,68,pass_mode,p);}if((proj_arc!=-1) && (proj_arc >= -0.08 && proj_arc <= 0.65)) {xsEffectAmount(0,proj,69,proj_arc,p);}}']

# %%
# 在名为 XS_FUNC_TITLE 的触发器条件中追加定义 UDF的XS功能
for trigger in trigger_mgr.triggers:
    if trigger.name == XS_FUNC_TITLE:
        # 将UDF导入场景
        for fn in udf_list:
            trigger.new_condition.script_call(fn)
print("UDF函数导入成功！")
# Out:
# UDF函数导入成功！

# %%
# 查看triggers列表中UDF添加情况
trigger_mgr.triggers[1].conditions
# Out:
# [Condition: 	{
#  		_instance_number_history: 	[
#  			1, 0
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: const float EPS=0.000001;const float PI=3.1416;const float E_=2.7183;const int Inf=32768;
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 1
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _EA(int mode=-1,int id_=0,int attr=-1,float val_=0.0,int p=-1){if(mode>=0 && mode<=9){xsEffectAmount(mode,id_,attr,val_,p);}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 2
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _Chat(string msg="",string color="",float val_=-32768){if(val_!=-32768){msg=color+msg+": "+val_;} else{msg=color+msg;} xsChatData(msg);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 3
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _BoolArr(int arr_len=1,bool val_=false,string arr_name=""){return (xsArrayCreateBool(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 4
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _IntArr(int arr_len=1,int val_=0,string arr_name=""){return (xsArrayCreateInt(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 5
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _FloatArr(int arr_len=1,float val_=0.0,string arr_name=""){return (xsArrayCreateFloat(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 6
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _StrArr(int arr_len=1,string val_="",string arr_name=""){return (xsArrayCreateString(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 7
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _VecArr(int arr_len=1,vector val_=cOriginVector,string arr_name=""){return (xsArrayCreateVector(arr_len,val_,arr_name));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 8
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _BArrG(int arr=-1,int index=0){return (xsArrayGetBool(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 9
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _IArrG(int arr=-1,int index=0){return (xsArrayGetInt(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 10
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float _FArrG(int arr=-1,int index=0){return (xsArrayGetFloat(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 11
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: string _SArrG(int arr=-1,int index=0){return (xsArrayGetString(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 12
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: vector _VArrG(int arr=-1,int index=0){return (xsArrayGetVector(arr,index));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 13
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _BArrS(int arr=-1,int index=0,bool val_=false){return (xsArraySetBool(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 14
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _IArrS(int arr=-1,int index=0,int val_=0){return (xsArraySetInt(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 15
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _FArrS(int arr=-1,int index=0,float val_=0.0){return (xsArraySetFloat(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 16
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _SArrS(int arr=-1,int index=0,string val_=""){return (xsArraySetString(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 17
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _VArrS(int arr=-1,int index=0,vector val_=cOriginVector){return (xsArraySetVector(arr,index,val_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 18
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _ArrSize(int arr=-1){return (xsArrayGetSize(arr));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 19
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _GameT(){ return (xsGetGameTime());}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 20
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _OC(int p=0,int unit=-1){return (xsGetObjectCount(p,unit));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 21
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _OCT(int p=0,int unit=-1){return (xsGetObjectCountTotal(p,unit));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 22
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _Victory(){return (xsGetVictoryCondition());}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 23
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _GPC(int p=0){return (xsGetPlayerCivilization(p));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 24
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float _PA(int p=0,int src_id=-1){return (xsPlayerAttribute(p,src_id));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 25
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _SPA(int p=0,int src_id=-1,float amt_=0.0){xsSetPlayerAttribute(p,src_id,amt_);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 26
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int _TV(int var_id=0){return (xsTriggerVariable(var_id));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 27
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void _STV(int var_id=0,int val_=0){xsSetTriggerVariable(var_id,val_);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 28
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _RT(int tech_id=-1,bool force=true,bool avilable=false,int p=-1){if(force && avilable) {return (false);}return (xsResearchTechnology(tech_id,force,avilable,p));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 29
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _PInGame(int p=0){return (xsGetPlayerInGame(p));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 30
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float round(float x_=0.0,int n=0){float num=0;int pn=pow(10,n);float pf=x_*pn;int ipf=1*pf; if(abs(pf-ipf)<0.5){num=1.0*ipf/pn;} else{num=1.0*(ipf+1)/pn;} return(num);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 31
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int floor(float x_=0.0){return(0+x_);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 32
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int ceil(float x_=0.0){int ix=x_; if(abs(x_-ix)>0){return(ix+1);} return(ix);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 33
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float _Float(float x_=0.0){return (x_-(0+x_));}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 34
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function:
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 35
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool _NOT(bool flag=true){if(flag){return(false);} return(true);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 36
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool xsNum2Bool(float x_=0.0){if(x_>0.0){return (true);} return (false);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 37
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int randLH(int low=0,int high=32768){return (xsGetRandomNumberLH(0,high-low)+low);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 38
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int randLI(bool sign_=false){static int sign=1; if(sign_){sign=0-sign;} int ri=xsGetRandomNumber(); int I=randLH(0,30519); if(I>=30518){ri=randLH(0,16693);} int LI=sign*(32767*I+ri); return(LI);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 39
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: float random(bool sign_=false){static float sign=1.0;if(sign_){sign=0.0-sign;}float rn=xsGetRandomNumber();int I=xsGetRandomNumberLH(0,31);if(I>=30){rn=xsGetRandomNumberLH(0,16990);}rn=0.000001*sign*(rn+I*32767);static int fix=1; fix=0-fix;if((rn>0.83&&rn<0.88)&&(fix==1)){rn=rn-0.72;}return (rn);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 40
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool xsProbability(float prob=0.5){float rp=xsGetRandomNumber();int I=xsGetRandomNumberLH(0,31);if(I>=30){rp=xsGetRandomNumberLH(0,16990);} rp=0.000001*(rp+32767*I);static int fix=1; fix=0-fix;if((rp>=0.83 && rp<=0.88) && fix==1){rp=rp-0.72;}if(rp <= prob){return (true);}return (false);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[
#  			1, 41
#  		]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void xsExit(bool exit=true){if(exit){xsChatData("%NULL");}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void unit_blast(int unit=-1,int blast_att=-1,int blast_def=-1,float blast_w=0.0,float blast_rate=0.0,int p=-1) {if(blast_att==0||blast_att==1||blast_att==2||blast_att==4||blast_att==64||blast_att==128) {xsEffectAmount(0,unit,44,blast_att,p);}if(blast_def==0||blast_def==1||blast_def==2||blast_def==4) {xsEffectAmount(0,unit,45,blast_def,p);}if(blast_w > 0.0) {xsEffectAmount(0,unit,22,blast_w,p);}if(blast_rate > 0.0 && blast_rate <= 1.0) {xsEffectAmount(0,unit,115,blast_rate,p);}else if(blast_rate < 0 && blast_rate > 0-255) {xsEffectAmount(0,unit,115,1*blast_rate,p);}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool unit_charges(int unit=-1,int charge_event=0,int charge_type=0,float max_charge=0.0,float recharge_rate=0.0,int p=-1,float charge_cd=-1) {if(charge_event==0||(charge_type<0||charge_type>4||charge_type==2)) {return (false);}if(charge_cd > 0) {recharge_rate=max_charge/charge_cd;}xsEffectAmount(0,unit,61,charge_event,p);xsEffectAmount(0,unit,62,charge_type,p);xsEffectAmount(0,unit,59,max_charge,p);xsEffectAmount(0,unit,60,recharge_rate,p);return (true);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: int unit_combats(int unit=-1,int ability=0,int p=-1) {if((unit>=0)&&(ability==0||ability==1||ability==2||ability==4 ||ability==8||ability==16||ability==32)){xsEffectAmount(0,unit,63,ability,p); return (ability);}return (-1);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void unit_traits(int unit1=-1,int _trait=0,int unit2=0,int p=-1) { if(_trait==0||_trait==1||_trait==2||_trait==16) {xsEffectAmount(0,unit1,54,_trait,p);}else if(_trait==4) {xsEffectAmount(0,unit1,54,4,p);}  else if(_trait==8 && (unit2>=0 && unit2<1800)) {xsEffectAmount(0,unit1,54,8,p);xsEffectAmount(0,unit2,54,8,p);xsEffectAmount(0,unit1,56,unit2,p);xsEffectAmount(0,unit2,56,unit1,p);}else {}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: bool units_transform(int units_arr=-1,int p=-1) {int arr_size=xsArrayGetSize(units_arr);if(arr_size < 2) {return (false);}else {int unit1= -1;int unit2= -1;for(i=0; <arr_size) {unit1=xsArrayGetInt(units_arr,i);if(i==arr_size-1) {unit2=xsArrayGetInt(units_arr,0);}else {unit2=xsArrayGetInt(units_arr,i+1);}if(unit1<=0||unit2<=0){continue;}xsEffectAmount(0,unit1,54,8,p);xsEffectAmount(0,unit1,56,unit2,p);}return (true);}return (false);}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void unit_cloths(int unit=-1,int icon=0,vector attack_img=cInvalidVector,vector stand_img=cInvalidVector,vector death_img=cInvalidVector,vector  move_img=cInvalidVector,int death=-1,int p=-1){if(unit>0 && (p>=0 && p<=8)) {if(icon > 0) {xsEffectAmount(0,unit,25,icon,p);}if(attack_img != cInvalidVector) {xsEffectAmount(0,unit,70,xsVectorGetX(attack_img),p);}if(stand_img != cInvalidVector) {int simg1 = xsVectorGetX(stand_img);int simg2 = xsVectorGetY(stand_img);if(simg1>0) {xsEffectAmount(0,unit,71,simg1,p);}if(simg2>0) {xsEffectAmount(0,unit,72,simg2,p);}}if(death_img != cInvalidVector) {int dimg1 = xsVectorGetX(death_img);int dimg2 = xsVectorGetY(death_img);if(dimg1>0) {xsEffectAmount(0,unit,73,dimg1,p);}if(dimg2>0) {xsEffectAmount(0,unit,74,dimg2,p);}}if(move_img != cInvalidVector) {int mimg1 = xsVectorGetX(move_img);int mimg2 = xsVectorGetY(move_img);if(mimg1>0) {xsEffectAmount(0,unit,75,mimg1,p);}if(mimg2>0) {xsEffectAmount(0,unit,76,mimg2,p);}}if(death>-1 && death<2000) {xsEffectAmount(0,unit,57,death,p);}}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void unit_projectiles(int unit=-1,int mproj=-1,int sproj=-1,int max_projs=1,int init_projs=1,int p=-1,float mpv=-1,float spv=-1,int mdu=-1,int sdu=-1,bool proj_sync=false) {if(mproj > 0) {xsEffectAmount(0,unit,16,mproj,p);}if(sproj > 0) {xsEffectAmount(0,unit,65,sproj,p);}if(max_projs>=init_projs && init_projs>=1) {xsEffectAmount(0,unit,107,max_projs,p);xsEffectAmount(0,unit,102,init_projs,p);}if(mpv > 0) {xsEffectAmount(0,mproj,5,mpv,p);}if(spv > 0) {xsEffectAmount(0,sproj,5,spv,p);}if(mdu > 0) {xsEffectAmount(0,mproj,57,mdu,p);}if(sdu > 0) {xsEffectAmount(0,sproj,57,sdu,p);}if(proj_sync) {xsEffectAmount(0,unit,63,16,p);}}
#  	},
#  Condition: 	{
#  		_instance_number_history: 	[]
#  		_uuid: c161100d-3007-4cb9-a4ab-bf7cf305f833
#  		condition_type: SCRIPT_CALL
#  		quantity: -1
#  		attribute: -1
#  		unit_object: -1
#  		next_object: -1
#  		object_list: -1
#  		source_player: -1
#  		technology: -1
#  		timer: -1
#  		area_x1: -1
#  		area_y1: -1
#  		area_x2: -1
#  		area_y2: -1
#  		object_group: -1
#  		object_type: -1
#  		ai_signal: -1
#  		inverted: -1
#  		variable: -1
#  		comparison: -1
#  		target_player: -1
#  		unit_ai_action: -1
#  		object_state: -1
#  		timer_id: -1
#  		victory_timer_type: -1
#  		include_changeable_weapon_objects: -1
#  		xs_function: void proj_smart_mode(int proj=-1,int smart_mode=-1,int hit_mode=-1,int pass_mode=-1,float proj_arc=-1,int p=-1) {if(smart_mode>=0 && smart_mode<=3){xsEffectAmount(0,proj,19,smart_mode,p);}if((hit_mode>=0 && hit_mode<=3)&&(pass_mode>=0 && pass_mode<=1)){xsEffectAmount(0,proj,67,hit_mode,p);xsEffectAmount(0,proj,68,pass_mode,p);}if((proj_arc!=-1) && (proj_arc >= -0.08 && proj_arc <= 0.65)) {xsEffectAmount(0,proj,69,proj_arc,p);}}
#  	}]

# %% [markdown]
# #### 从以上结果看到，在原先定义的XS基本函数的后面，又追加定义了UDF的XS功能。

# %%
#脚本导入成功后，将场景进行保存
scenario.write_to_file(des_path)
# Out:
# [11:38:34] Reconstructing sections and structs from managers...
# 	✔ MessageManagerssageManager...
# 	✔ PlayerManagerlayerManager...
# 	✔ MapManagerg MapManager...
# 	✔ UnitManager UnitManager...
# 	✔ TriggerManageriggerManager...
# 	✔ XsManagerng XsManager...
# 	✔ OptionManagerptionManager...
# [11:38:35] Reconstruction finished successfully.
#
# [11:38:35] File writing from structure started...
# 	✔ FileHeaderg FileHeader...
# 	✔ DataHeaderg DataHeader...
# 	✔ Messagesing Messages...
# 	✔ Cinematicsg Cinematics...
# 	✔ BackgroundImagekgroundImage...
# 	✔ PlayerDataTwolayerDataTwo...
# 	✔ GlobalVictorylobalVictory...
# 	✔ Diplomacyng Diplomacy...
# 	✔ Optionsting Options...
# 	✔ Maptructing Map...
# 	✔ Unitsucting Units...
# 	✔ Triggersing Triggers...
# 	✔ Filesucting Files...
# [11:38:36] File writing finished successfully.
# [11:38:36] File successfully written to: 'C:/Users/babycat/Games/Age of Empires 2 DE/76561198386517457/resources/_common/scenario/Sanatorium [XS_ALL].aoe2scenario'
# [11:38:36] Execution time from scenario read: 787.64s

# %% [markdown]
# #### 我们用地图编辑器打开导出的场景，切换到“触发”选项卡，可以看到XS脚本已经成功导入到场景里了。
#
# <img src="./images/doc-104.png" width=600 height=900 align="center">

# %% [markdown]
# ### <font color="red">ASP导入XS脚本的优势：</font>
# #### 相比手动在场景中添加XS脚本，ASP导入脚本有以下几个优势：
#  - <font color="blue">**批量导入：ASP可以将文件中定义好的脚本批量导入场景，省时省力**</font>
#  - <font color="blue">**修改方便：若要修改XS函数定义，只需将修改后的文件进行导入，覆盖原先的定义即可（再次导入前，先将XS所在触发的条件列表清空：`trigger_mgr.triggers[1].conditions=[]`）**（此处triggers[1]触发用于定义脚本）</font>
#  - <font color="blue">**导入脚本的字符个数不受限制（若手动向条件脚本调用中添加内容，脚本字符个数不能超过256）**</font>
